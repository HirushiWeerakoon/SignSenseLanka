# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, Input
from tensorflow.keras.callbacks import EarlyStopping
import matplotlib.pyplot as plt

# %%
# Load preprocessed data
X_train = np.load('../data/X_train.npy')
X_test = np.load('../data/X_test.npy')
y_train = np.load('../data/y_train.npy')
y_test = np.load('../data/y_test.npy')
classes = np.load('../data/classes.npy')

# %%
num_classes = len(classes)

# %%
# Define the model
model = Sequential([
    Input(shape=(21, 3, 1)),
    Conv2D(32, (3, 3), activation='relu', padding='same'),
    MaxPooling2D((2, 2), padding='same'),
    Dropout(0.25),
    Conv2D(64, (3, 3), activation='relu', padding='same'),
    MaxPooling2D((2, 2), padding='same'),
    Dropout(0.25),
    Flatten(),
    Dense(128, activation='relu'),
    Dropout(0.5),
    Dense(num_classes, activation='softmax')
])

# %%
# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
# Define early stopping
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

# %%
# Train the model
history = model.fit(X_train, y_train, epochs=100, validation_data=(X_test, y_test), callbacks=[early_stopping])
# Out:
# Epoch 1/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.2515 - loss: 2.3525 - val_accuracy: 0.9690 - val_loss: 0.2416
# Epoch 2/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.8704 - loss: 0.3930 - val_accuracy: 0.9812 - val_loss: 0.1029
# Epoch 3/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9432 - loss: 0.2088 - val_accuracy: 0.9850 - val_loss: 0.0730
# Epoch 4/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9574 - loss: 0.1563 - val_accuracy: 0.9880 - val_loss: 0.0641
# Epoch 5/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9693 - loss: 0.1183 - val_accuracy: 0.9877 - val_loss: 0.0495
# Epoch 6/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9697 - loss: 0.1056 - val_accuracy: 0.9877 - val_loss: 0.0506
# Epoch 7/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9770 - loss: 0.0910 - val_accuracy: 0.9883 - val_loss: 0.0427
# Epoch 8/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9780 - loss: 0.0830 - val_accuracy: 0.9898 - val_loss: 0.0411
# Epoch 9/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9798 - loss: 0.0726 - val_accuracy: 0.9930 - val_loss: 0.0289
# Epoch 10/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9797 - loss: 0.0698 - val_accuracy: 0.9923 - val_loss: 0.0306
# Epoch 11/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9821 - loss: 0.0668 - val_accuracy: 0.9895 - val_loss: 0.0318
# Epoch 12/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9863 - loss: 0.0521 - val_accuracy: 0.9923 - val_loss: 0.0260
# Epoch 13/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9854 - loss: 0.0496 - val_accuracy: 0.9915 - val_loss: 0.0287
# Epoch 14/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9864 - loss: 0.0477 - val_accuracy: 0.9910 - val_loss: 0.0235
# Epoch 15/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9869 - loss: 0.0429 - val_accuracy: 0.9940 - val_loss: 0.0199
# Epoch 16/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9880 - loss: 0.0430 - val_accuracy: 0.9935 - val_loss: 0.0182
# Epoch 17/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9893 - loss: 0.0439 - val_accuracy: 0.9923 - val_loss: 0.0243
# Epoch 18/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9866 - loss: 0.0416 - val_accuracy: 0.9945 - val_loss: 0.0163
# Epoch 19/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9869 - loss: 0.0407 - val_accuracy: 0.9920 - val_loss: 0.0182
# Epoch 20/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9897 - loss: 0.0359 - val_accuracy: 0.9948 - val_loss: 0.0157
# Epoch 21/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9909 - loss: 0.0296 - val_accuracy: 0.9958 - val_loss: 0.0124
# Epoch 22/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9880 - loss: 0.0393 - val_accuracy: 0.9948 - val_loss: 0.0117
# Epoch 23/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9911 - loss: 0.0310 - val_accuracy: 0.9933 - val_loss: 0.0170
# Epoch 24/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9912 - loss: 0.0308 - val_accuracy: 0.9952 - val_loss: 0.0116
# Epoch 25/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9912 - loss: 0.0277 - val_accuracy: 0.9952 - val_loss: 0.0130
# Epoch 26/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.9909 - loss: 0.0283 - val_accuracy: 0.9935 - val_loss: 0.0157
# Epoch 27/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9930 - loss: 0.0243 - val_accuracy: 0.9950 - val_loss: 0.0134
# Epoch 28/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9912 - loss: 0.0282 - val_accuracy: 0.9945 - val_loss: 0.0140
# Epoch 29/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9934 - loss: 0.0245 - val_accuracy: 0.9952 - val_loss: 0.0121

# %%
# Save the model
model.save('../model/hand_sign_model.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
# Plot evaluation metrics
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.legend()
plt.title('Accuracy')
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.legend()
plt.title('Loss')
plt.show()
